# %% [markdown]
# # Download data source files

# %%
import requests
import zipfile
import os
import pandas as pd

data_path = "../data/raw"

def save_file(url):
    file_name = url.split('/')[-1]
    zip_path = os.path.join(data_path, file_name)
    extracted_name = os.path.splitext(file_name)[0]  # strips the extension
    
    if any(f.startswith(extracted_name) for f in os.listdir(data_path)):
        print(f"Already exists, skipping: {extracted_name}")
        return

    # 1. Create folder if it doesn't exist
    os.makedirs(data_path, exist_ok=True)
    
    # 2. Download the zip file
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Referer": "https://www.iedb.org/",  # tells the server you're coming from their site
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
    }
    response = requests.get(url, stream=True, headers=headers)
    response.raise_for_status()
    
    with open(zip_path, "wb") as f:
        for chunk in response.iter_content(chunk_size=8192):
            f.write(chunk)
    
    print(f"Downloaded: {zip_path}")
    
    # 3. Unzip the file
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall(data_path)
    
    print(f"Extracted to: {data_path}")
    
    # 4. Delete the zip file
    os.remove(zip_path)
    print("Zip file deleted.")

# %%
files = [
    "https://www.iedb.org/downloader.php?file_name=doc/tcell_full_v3.zip",
    "https://www.iedb.org/downloader.php?file_name=doc/bcell_full_v3_single_file.zip",
    "https://www.iedb.org/downloader.php?file_name=doc/antigen_full_v3.zip",
]

# %%
for file in files:
    save_file(file)
# Out:
# Downloaded: ../data/raw\tcell_full_v3.zip
# Extracted to: ../data/raw
# Zip file deleted.
# Downloaded: ../data/raw\bcell_full_v3_single_file.zip
# Extracted to: ../data/raw
# Zip file deleted.
# Downloaded: ../data/raw\antigen_full_v3.zip
# Extracted to: ../data/raw
# Zip file deleted.

# %% [markdown]
# # Merge all data to one processed file

# %%
df = pd.read_csv(f"{data_path}/bcell_full_v3.csv")
# Out:
# C:\Users\Joaquin\AppData\Local\Temp\ipykernel_15476\2358830.py:1: DtypeWarning: Columns (0: Reference.2, 1: Reference.3, 2: Reference.6, 3: Epitope.4, 4: Epitope.5, 5: Epitope.6, 6: Epitope.7, 7: Epitope.8, 8: Epitope.9, 9: Epitope.10, 10: Epitope.11, 11: Epitope.12, 12: Epitope.13, 13: Epitope.14, 14: Epitope.15, 15: Epitope.16, 16: Epitope.17, 17: Epitope.18, 18: Related Object, 19: Related Object.1, 20: Related Object.2, 21: Related Object.3, 22: Related Object.4, 23: Related Object.5, 24: Related Object.6, 25: Related Object.7, 26: Related Object.8, 27: Related Object.9, 28: Related Object.10, 29: Related Object.11, 30: Related Object.12, 31: Related Object.13, 32: Related Object.14, 33: Host.2, 34: Host.3, 35: Host.4, 36: Host.5, 37: Host.6, 38: 1st in vivo Process.1, 39: 1st in vivo Process.2, 40: 1st in vivo Process.3, 41: 1st immunogen, 42: 1st immunogen.1, 43: 1st immunogen.2, 44: 1st immunogen.3, 45: 1st immunogen.4, 46: 1st immunogen.5, 47: 1st immunogen.6, 48: 1st immunog
# ...

# %%
df.head(8)
# Out:
#                        Assay ID                          Reference  \
# 0                      IEDB IRI                           IEDB IRI
# 1   http://www.iedb.org/assay/5  http://www.iedb.org/reference/271
# 2  http://www.iedb.org/assay/14  http://www.iedb.org/reference/276
# 3  http://www.iedb.org/assay/31  http://www.iedb.org/reference/278
# 4  http://www.iedb.org/assay/32  http://www.iedb.org/reference/279
# 5  http://www.iedb.org/assay/33  http://www.iedb.org/reference/280
# 6  http://www.iedb.org/assay/82  http://www.iedb.org/reference/285
# 7  http://www.iedb.org/assay/98  http://www.iedb.org/reference/290
#
#   Reference.1 Reference.2    Reference.3  \
# 0        Type        PMID  Submission ID
# 1  Literature     7629116            NaN
# 2  Literature     9698550            NaN
# 3  Literature    10488102            NaN
# 4  Literature    12842050            NaN
# 5  Literature    11183781            NaN
# 6  Literature    15710332            NaN
# ...
